# %%
import numpy as np
import cv2 as cv
from skimage import io
import matplotlib.pyplot as plt

# %%
src = cv.imread('pout.jpg',0)
plt.imshow(src, cmap='gray')

# %%
#High-pass Gaussian filter
(P, Q) = npFFTS.shape
H = np.zeros((P,Q))
D0 = 40
for u in range(P):
    for v in range(Q):
        H[u, v] = 1.0 - np.exp(- ((u - P / 2.0) ** 2 + (v - Q / 2.0) ** 2) / (2 * (D0 ** 2)))
k1 = 0.5 ; k2 = 0.75
HFEfilt = k1 + k2 * H # Apply High-frequency emphasis
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-a8b65c930b7c> in <module>
#       1 #High-pass Gaussian filter
# ----> 2 (P, Q) = npFFTS.shape
#       3 H = np.zeros((P,Q))
#       4 D0 = 40
#       5 for u in range(P):
#
# NameError: name 'npFFTS' is not defined

# %%
sharp = cv.addWeighted(dst, 1.5, src, -0.5, 0, sharp) 
plt.imshow(sharp, cmap='gray')
